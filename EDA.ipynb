# %% [markdown]
# # Exploratory Data Analysis on Educational Data
#
# In this notebook, we explore the performance of public school students in the city of Natal in Brazil. The purpose of this exploration is to contain an initial analysis of the possibilities of using machine learning in the data. The data are presented under tuples of students, with their performances and school attendance in the subjects of Portuguese and Mathematics. In addition, the location of the student's residence is provided, which brings more value to the dataset. We add data from the neighborhood where each student lives to enrich the analysis and to observe how important it is in their classroom performance.

# %% [markdown]
# ### Import dependencies and loading the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shapely
import geopandas as gpd
import warnings

plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'

warnings.filterwarnings('ignore')
folder = '/home/adelsondias/Repos/educational-analytics/data/'

# %%
students = pd.read_csv(folder+'alunos.csv')
students.head()
# Out:
#       ID              direc municipio                 escola  \
# 0   9599  01ª DIREC - NATAL     NATAL  CE ALFERES TIRADENTES
# 1   9595  01ª DIREC - NATAL     NATAL  CE ALFERES TIRADENTES
# 2   9606  01ª DIREC - NATAL     NATAL  CE ALFERES TIRADENTES
# 3  93948  01ª DIREC - NATAL     NATAL  CE ALFERES TIRADENTES
# 4   9582  01ª DIREC - NATAL     NATAL  CE ALFERES TIRADENTES
#
#                               etapa   serie     turno    turma  \
# 0  ENSINO FUNDAMENTAL - ANOS FINAIS  6º Ano  MATUTINO  EFAFM6A
# 1  ENSINO FUNDAMENTAL - ANOS FINAIS  6º Ano  MATUTINO  EFAFM6A
# 2  ENSINO FUNDAMENTAL - ANOS FINAIS  6º Ano  MATUTINO  EFAFM6A
# 3  ENSINO FUNDAMENTAL - ANOS FINAIS  6º Ano  MATUTINO  EFAFM6A
# 4  ENSINO FUNDAMENTAL - ANOS FINAIS  6º Ano  MATUTINO  EFAFM6A
#
#           disciplina  frequencia  media_final  situacao  latitude  longitude
# 0  Língua Portuguesa        92.5          6.9  APROVADO -5.885477 -35.168400
# ...

# %% [markdown]
# ## 0. Preprocessing
#
#
# ### 0.1. Cleaning the data

# %%
students['serie'] = students['serie'].apply(lambda x: x.upper())
students = students.loc[students['etapa'].isin(students['etapa'].value_counts()[:5].index)]
students['etapa'] = students['etapa'].replace({'CEJA ENSINO MEDIO': 'EJA - ENSINO MÉDIO'})
students['serie'] = students['serie'].replace({'2º PERÍODO (2ª SÉRIE)':'2ª SÉRIE',
 '3º PERÍODO (3ª SÉRIE)':'3ª SÉRIE',
 '1º PERÍODO (1ª SÉRIE)':'1ª SÉRIE'                                 
})
students['media_final'] = students['media_final'].astype(float)
students['frequencia'] = students['frequencia'].astype(float)

# %% [markdown]
# ### 0.2. Transforming the dataframe to a geodataframe

# %%
students['geometry'] = students.apply(lambda x: shapely.geometry.Point([x['longitude'],x['latitude']]), axis=1)
students = gpd.GeoDataFrame(students)
students.head()
# Out:
#       ID              direc municipio                 escola  \
# 0   9599  01ª DIREC - NATAL     NATAL  CE ALFERES TIRADENTES
# 1   9595  01ª DIREC - NATAL     NATAL  CE ALFERES TIRADENTES
# 2   9606  01ª DIREC - NATAL     NATAL  CE ALFERES TIRADENTES
# 3  93948  01ª DIREC - NATAL     NATAL  CE ALFERES TIRADENTES
# 4   9582  01ª DIREC - NATAL     NATAL  CE ALFERES TIRADENTES
#
#                               etapa   serie     turno    turma  \
# 0  ENSINO FUNDAMENTAL - ANOS FINAIS  6º ANO  MATUTINO  EFAFM6A
# 1  ENSINO FUNDAMENTAL - ANOS FINAIS  6º ANO  MATUTINO  EFAFM6A
# 2  ENSINO FUNDAMENTAL - ANOS FINAIS  6º ANO  MATUTINO  EFAFM6A
# 3  ENSINO FUNDAMENTAL - ANOS FINAIS  6º ANO  MATUTINO  EFAFM6A
# 4  ENSINO FUNDAMENTAL - ANOS FINAIS  6º ANO  MATUTINO  EFAFM6A
#
#           disciplina  frequencia  media_final  situacao  latitude  longitude  \
# 0  Língua Portuguesa        92.5          6.9  APROVADO -5.885477 -35.168400
# ...

# %% [markdown]
# ## 1. Exploratory Data Analysis

# %%
districts = gpd.read_file(folder+'bairros_natal_populacao2016.geojson')
sd = gpd.sjoin(students, districts, op='within')
sd = sd.dropna()

fig, ax = plt.subplots(figsize=(4,6))
districts.plot(ax=ax, color='white', edgecolor='black', label='Districts')
sd.plot(ax=ax, label='Students')
ax.legend(fontsize=14)
ax.axis('off');

# %%
fig, ax = plt.subplots(figsize=(14,5))

sns.violinplot(y='media_final', x='serie', hue='disciplina', data=sd, palette='Blues', split=True, ax=ax,
              order=['4º ANO','5º ANO','6º ANO','7º ANO','8º ANO','9º ANO','1ª SÉRIE','2ª SÉRIE', '3ª SÉRIE', 'BLOCO A', 'BLOCO B'])

ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_ylim([0,10])
ax.set_ylabel('Média',fontsize=18)
ax.set_xlabel('Série',fontsize=18)
ax.legend(fontsize=14, loc=3)
ax.grid()
plt.tight_layout()
plt.savefig('plots/media_final_serie.pdf',dpi=200)

# %%
fig, ax = plt.subplots(figsize=(14,5))

sns.violinplot(y='frequencia', x='serie', hue='disciplina', data=sd, palette='Blues', split=True, ax=ax,
              order=['4º ANO','5º ANO','6º ANO','7º ANO','8º ANO','9º ANO','1ª SÉRIE','2ª SÉRIE', '3ª SÉRIE', 'BLOCO A', 'BLOCO B'])

ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_ylim([0,100])
ax.set_ylabel('Média',fontsize=18)
ax.set_xlabel('Série',fontsize=18)
ax.legend(fontsize=14, loc=3)
ax.grid()
plt.tight_layout()
plt.savefig('plots/frequencia_serie.pdf',dpi=200)

# %%
fig, ax = plt.subplots(figsize=(14,5))

sns.countplot(x='serie', hue='situacao', data=sd, ax=ax, palette='Blues_r', edgecolor='black', linewidth=1,
              order=['4º ANO','5º ANO','6º ANO','7º ANO','8º ANO','9º ANO','1ª SÉRIE','2ª SÉRIE', '3ª SÉRIE', 'BLOCO A', 'BLOCO B'])

ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_ylabel('Count',fontsize=18)
ax.set_xlabel('Série',fontsize=18)
ax.legend(fontsize=14, loc=2)
ax.grid()
plt.tight_layout()
plt.savefig('plots/aprovacao_serie.pdf',dpi=200)

# %%
fig, ax = plt.subplots(figsize=(14,8), ncols=2)
sns.barplot(y='BAIRRO',x='media_final',data=sd.groupby('BAIRRO').mean()['media_final'].reset_index().sort_values('media_final', ascending=False), 
            palette='Blues_r', edgecolor='black', linewidth=1, ax=ax[0])
sns.barplot(y='BAIRRO',x='frequencia',data=sd.groupby('BAIRRO').mean()['frequencia'].reset_index().sort_values('frequencia', ascending=False), 
            palette='Blues_r', edgecolor='black', linewidth=1, ax=ax[1])
# districts.set_index('BAIRRO').join(ab.groupby('BAIRRO').mean()['media_final']).drop(['Parque das Dunas']).plot(column='media_final', cmap='Spectral', edgecolor='black',ax=ax[1][0])
# districts.set_index('BAIRRO').join(ab.groupby('BAIRRO').mean()['frequencia']).drop(['Parque das Dunas']).plot(column='frequencia', cmap='Spectral', edgecolor='black',ax=ax[1][1])

ax[0].set_xlim([4.25,6.5])
ax[1].set_xlim([80,100])
ax[0].xaxis.set_tick_params(labelsize=14)
ax[0].yaxis.set_tick_params(labelsize=14)
ax[1].xaxis.set_tick_params(labelsize=14)
ax[1].yaxis.set_tick_params(labelsize=14)
ax[0].set_ylabel('District',fontsize=18)
ax[1].set_ylabel('District',fontsize=0)
ax[0].set_xlabel('Média final',fontsize=18)
ax[1].set_xlabel('Frequencia',fontsize=18)
plt.tight_layout()
plt.savefig(folder+'../plots/stats_bairro.pdf',dpi=200)

# %% [markdown]
# ## 1.a. Addressing crime deprivation index
#
# ### 1.a.1. Aggregating by district

# %%
df = pd.DataFrame()
crimes = {}
for i,crimetype in enumerate(['burglary','violent-lethal','drugs']):
    crimes[crimetype] = pd.read_csv(folder+'natal_bairros_{}_dens.csv'.format(crimetype),header=-1)
    crimes[crimetype].columns=['BAIRRO','dens_crimes_bairro_{}'.format(crimetype)]
    crimes[crimetype].set_index('BAIRRO', inplace=True)
    df = pd.concat([df, crimes[crimetype]],axis=1)
crimes = df
crimes.head()
# Out:
#                 dens_crimes_bairro_burglary  \
# BAIRRO
# Alecrim                            1.272815
# Areia Preta                        2.400063
# Barro Vermelho                     1.874693
# Bom Pastor                         0.920760
# Candelária                         0.882009
#
#                 dens_crimes_bairro_violent-lethal  dens_crimes_bairro_drugs
# BAIRRO
# Alecrim                                  1.585686                  0.362646
# Areia Preta                              4.609644                  1.333368
# Barro Vermelho                           0.866237                  0.426654
# Bom Pastor                               3.056215                  0.665780
# Candelária                               0.502166                  0.152903

# %%
fig, ax = plt.subplots(figsize=(14,8), ncols=3)

sns.barplot(data=crimes.reset_index().sort_values('dens_crimes_bairro_burglary', ascending=False),
            x='dens_crimes_bairro_burglary', y='BAIRRO',ax=ax[0], palette='Blues_r', edgecolor='black', linewidth=1,)
sns.barplot(data=crimes.reset_index().sort_values('dens_crimes_bairro_violent-lethal', ascending=False),
            x='dens_crimes_bairro_violent-lethal', y='BAIRRO',ax=ax[1], palette='Blues_r', edgecolor='black', linewidth=1,)
sns.barplot(data=crimes.reset_index().sort_values('dens_crimes_bairro_drugs', ascending=False),
            x='dens_crimes_bairro_drugs', y='BAIRRO',ax=ax[2], palette='Blues_r', edgecolor='black', linewidth=1,)

ax[0].xaxis.set_tick_params(labelsize=14)
ax[0].yaxis.set_tick_params(labelsize=14)
ax[1].xaxis.set_tick_params(labelsize=14)
ax[1].yaxis.set_tick_params(labelsize=14)
ax[2].xaxis.set_tick_params(labelsize=14)
ax[2].yaxis.set_tick_params(labelsize=14)
ax[0].set_ylabel('District',fontsize=18)
ax[1].set_ylabel('District',fontsize=0)
ax[2].set_ylabel('District',fontsize=0)
ax[0].set_xlabel('CVP crimes',fontsize=18)
ax[1].set_xlabel('CVLI crimes',fontsize=18)
ax[2].set_xlabel('TREAD crimes',fontsize=18)

fig.tight_layout()
fig.savefig(folder+'../plots/stats_bairro_crimes.pdf',dpi=200)

# %%
sd = sd.join(crimes, on='BAIRRO')

# %% [markdown]
# ### 1.a.1. Density of crimes around the students

# %%
from sklearn.neighbors import KernelDensity

crimes_data = {}
X_ = pd.DataFrame()
for crimetag in ['burglary','violent-lethal','drugs']:
    print(crimetag)
    crimes_data[crimetag] = pd.read_csv(folder+'natal_crimes_{}.csv'.format(crimetag))
    kde = KernelDensity(bandwidth=0.1/69, kernel='exponential', metric='haversine').fit(crimes_data[crimetag][['lon','lat']].sample(frac=0.5))
    X = pd.DataFrame(kde.score_samples(sd[['longitude','latitude']]),
                         index=sd.index, columns=['kde_{}'.format(crimetag)])
    X_ = pd.concat([X_,X],axis=1)
# Out:
# burglary
# violent-lethal
# drugs

# %%
X_.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9970801630>,
# ...
#       dtype=object)

# %%
sd = sd.join(X_)

# %% [markdown]
# ## 1. Predictive Analysis

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ### 1.1. Approved/Reproved classification

# %%
# Features
features = ['frequencia','escola','serie','turno','REG_ADM','populacao2016','densidade2016','kde_burglary','kde_violent-lethal','kde_drugs']
X = sd.copy(deep=True)[features]
for feature in features[1:5]: #'REG_ADM', 'populacao2016','densidade2016'
    X[feature] = LabelEncoder().fit_transform(X[feature]) 

y = LabelEncoder().fit_transform(sd['situacao']) 


# Model selection
pgrid = {
    'n_estimators': [100, 200],
    'max_depth':[3, 5],
    'max_features':[0.8, 1]
}
clf = RandomizedSearchCV(RandomForestClassifier(), param_distributions=pgrid, cv=5, n_iter=1, n_jobs=-1)
clf.fit(X,y)
print('Accuracy:', clf.best_score_)
# Out:
# Accuracy: 0.801100782778865

# %%
fi = pd.DataFrame(clf.best_estimator_.feature_importances_, index=X.columns, columns=['Importance']).reset_index()

fig, ax = plt.subplots(figsize=(6,6))
sns.barplot(x='Importance',y='index',data=fi.sort_values('Importance',ascending=False))
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_ylabel('Feature',fontsize=18)
ax.set_xlabel('Importance',fontsize=18)
ax.grid()
plt.tight_layout()
plt.title("[Approved/Reproved Classification]\n Feature Importance Analysis\n", fontsize=18)
plt.savefig('plots/clf_featureimportance.pdf',dpi=200)

# %% [markdown]
# ## 1.2. Classroom performance regression

# %%
# Features
features = ['frequencia','escola','serie','turno','REG_ADM','populacao2016','densidade2016', 'kde_burglary','kde_violent-lethal','kde_drugs']
X = sd.copy(deep=True)[features]
for feature in features[1:5]: # escola, serie, turno, reg_adm
    X[feature] = LabelEncoder().fit_transform(X[feature]) 

y = sd['media_final']


# Model selection
pgrid = {
    'n_estimators': [100, 200],
    'max_depth':[3, 5],
    'max_features':[0.8, 1]
}
reg = RandomizedSearchCV(RandomForestRegressor(), param_distributions=pgrid, cv=5, n_iter=1, n_jobs=-1, 
                         scoring='neg_mean_squared_error')
reg.fit(X,y)
print('RMSE:', np.sqrt(-reg.best_score_))
# Out:
# RMSE: 2.4995266796854114

# %%
fi = pd.DataFrame(reg.best_estimator_.feature_importances_, index=X.columns, columns=['Importance']).reset_index()

fig, ax = plt.subplots(figsize=(6,6))
sns.barplot(x='Importance',y='index',data=fi.sort_values('Importance',ascending=False))
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_ylabel('Feature',fontsize=18)
ax.set_xlabel('Importance',fontsize=18)
ax.grid()
plt.tight_layout()
plt.title('[Student Performance Regression]\nFeature Importance Analysis\n', fontsize=18)
plt.savefig('plots/reg_featureimportance.pdf',dpi=200)

# %% [markdown]
# ## 1.3. Correlogram of features

# %%
X['situacao'] = 2-LabelEncoder().fit_transform(sd['situacao']) 
X['media_final'] = sd['media_final']

# %%
fig, ax = plt.subplots(figsize=(10,10))

corr = X.corr()
cmap = sns.diverging_palette(220, 10, as_cmap=True)
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
ax.xaxis.set_tick_params(labelsize=18)
ax.yaxis.set_tick_params(labelsize=18)
ax.set_title('Correlogram Analysis of Students Aspects',fontsize=24)
plt.tight_layout()
plt.savefig('plots/correlogram_features.pdf',dpi=200)
